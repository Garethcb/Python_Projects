# %% [markdown]
# ## Import Python Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import concurrent.futures
import requests
import re
from bs4 import BeautifulSoup
from urllib.request import Request, urlopen
import seaborn as sns
import klib
import lazypredict
import requests
import scipy.stats

pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)

# %% [markdown]
# ## Webscrapping Our Data Using BeautifulSoup

# %%
# Using Carsguide.com.au to webscrappe car price and associatted features.
# In order to scrape accross multiples pages via toggle menu each webpage url differs by ascends in multiples of 12

loop = [x for x in range(18900) if x%12==0] # creating a list of 12 to loop through
base_url = 'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=0&searchLimit=12'
pages = requests.get(base_url)
soup = BeautifulSoup(pages.text,'lxml')

# %%
# looping through list in order to append each pages url to the new_urls_list
new_urls_list = []
for number in loop:
    new_urls_list.append(base_url.split('set=')[0]+'set='+str(number)+'&searchLimit=12')
new_urls_list
# Out:
# ['https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=0&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=12&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=24&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=36&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=48&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=60&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=72&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=84&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=96&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=108&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=120&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=132&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=144&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=156&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=168&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=180&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=192&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=204&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=216&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=228&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=240&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=252&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=264&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=276&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=288&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=300&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=312&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=324&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=336&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=348&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=360&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=372&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=384&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=396&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=408&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=420&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=432&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=444&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=456&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=468&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=480&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=492&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=504&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=516&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=528&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=540&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=552&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=564&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=576&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=588&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=600&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=612&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=624&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=636&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=648&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=660&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=672&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=684&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=696&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=708&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=720&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=732&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=744&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=756&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=768&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=780&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=792&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=804&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=816&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=828&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=840&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=852&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=864&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=876&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=888&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=900&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=912&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=924&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=936&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=948&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=960&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=972&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=984&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=996&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1008&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1020&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1032&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1044&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1056&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1068&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1080&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1092&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1104&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1116&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1128&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1140&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1152&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1164&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1176&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1188&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1200&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1212&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1224&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1236&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1248&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1260&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1272&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1284&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1296&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1308&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1320&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1332&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1344&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1356&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1368&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1380&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1392&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1404&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1416&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1428&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1440&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1452&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1464&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1476&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1488&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1500&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1512&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1524&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1536&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1548&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1560&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1572&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1584&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1596&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1608&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1620&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1632&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1644&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1656&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1668&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1680&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1692&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1704&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1716&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1728&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1740&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1752&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1764&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1776&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1788&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1800&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1812&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1824&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1836&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1848&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1860&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1872&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1884&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1896&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1908&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1920&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1932&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1944&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1956&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1968&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1980&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=1992&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2004&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2016&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2028&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2040&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2052&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2064&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2076&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2088&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2100&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2112&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2124&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2136&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2148&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2160&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2172&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2184&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2196&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2208&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2220&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2232&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2244&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2256&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2268&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2280&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2292&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2304&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2316&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2328&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2340&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2352&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2364&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2376&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2388&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2400&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2412&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2424&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2436&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2448&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2460&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2472&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2484&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2496&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2508&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2520&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2532&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2544&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2556&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2568&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2580&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2592&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2604&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2616&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2628&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2640&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2652&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2664&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2676&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2688&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2700&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2712&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2724&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2736&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2748&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2760&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2772&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2784&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2796&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2808&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2820&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2832&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2844&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2856&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2868&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2880&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2892&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2904&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2916&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2928&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2940&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2952&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2964&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2976&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=2988&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3000&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3012&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3024&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3036&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3048&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3060&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3072&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3084&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3096&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3108&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3120&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3132&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3144&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3156&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3168&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3180&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3192&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3204&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3216&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3228&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3240&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3252&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3264&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3276&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3288&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3300&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3312&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3324&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3336&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3348&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3360&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3372&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3384&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3396&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3408&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3420&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3432&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3444&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3456&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3468&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3480&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3492&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3504&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3516&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=3528&searchLimit=12',
# ...
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10836&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10848&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10860&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10872&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10884&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10896&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10908&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10920&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10932&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10944&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10956&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10968&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10980&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=10992&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11004&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11016&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11028&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11040&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11052&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11064&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11076&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11088&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11100&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11112&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11124&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11136&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11148&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11160&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11172&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11184&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11196&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11208&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11220&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11232&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11244&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11256&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11268&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11280&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11292&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11304&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11316&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11328&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11340&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11352&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11364&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11376&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11388&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11400&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11412&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11424&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11436&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11448&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11460&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11472&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11484&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11496&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11508&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11520&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11532&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11544&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11556&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11568&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11580&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11592&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11604&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11616&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11628&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11640&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11652&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11664&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11676&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11688&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11700&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11712&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11724&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11736&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11748&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11760&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11772&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11784&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11796&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11808&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11820&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11832&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11844&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11856&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11868&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11880&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11892&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11904&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11916&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11928&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11940&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11952&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11964&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11976&searchLimit=12',
#  'https://www.carsguide.com.au/buy-a-car/all-new-and-used/qld/all-locations/all-bodytypes/all-makes?distanceFromMe=Brisbane,QLD&searchOffset=11988&searchLimit=12',
#  ...]

# %%
# Diving deeper into the individual advertisment requires scraping those links per page
car_link_list = []
for new in new_urls_list: 
    link_pages = requests.get(new)
    link_soup = BeautifulSoup(link_pages.text,'lxml')
    for link in link_soup.find_all('a', attrs={'class': "carListing carListing-slideBtn"}): # Scrapping link
        car_link_list.append('https://www.carsguide.com.au/'+link.get('href')) # Appending each individual add link

# %%
# Multiprocessing runs faster as there are over 18000 links to scrape
listing = []
def transform(final_link):
    web_page = requests.get(final_link)
    web_soup = BeautifulSoup(web_page.text,"lxml")
    details = [x.get_text() for x in web_soup.find_all('table',{'class':"details-page-tab-table more-details clearfix"})]
    listing.append(details)
    return

with concurrent.futures.ThreadPoolExecutor() as executor:
    executor.map(transform,car_link_list)

# %% [markdown]
# ## Creating Our Pandas Dataframe and Saving Our Data

# %%
df = pd.DataFrame(listing)

# Saving our data so we do not have to scrape again
df.to_csv('CarSales_Scrape.csv',index=False)

# %%
# Reading in our saved dataframe and viewing the first 5 rows
df = pd.read_csv('CarSales_Scrape.csv')
df.head(5)
# Out:
#                                                    0
# 0  \n\nPrice\n$18,990                        Calc...
# 1  \n\nPrice\n$54,990                        Calc...
# 2  \n\nPrice\n$36,550                        Calc...
# 3  \n\nPrice\n$10,680                        Calc...
# 4  \n\nPrice\n$27,990                      \n\n\n...

# %%
# This function allows for the creation of columns features while cleaning some dirty syntax associated with scrapping
def clean(df,col,split_on,second_split,column_name):
    df[column_name] = df[col].str.split(split_on).str[1].str.strip()
    df[column_name] = df[column_name].str.split(second_split).str[0].str.strip()
    
# Col in our function is the original 0 column of our dataframe.
# split_on is what we want to split on.
# second_split is what we want our second split to be on.
# column_name is what we want our new column to be named.

# %% [markdown]
# ## Data Cleaning

# %%
clean(df,'0','Price','Cal','Price')
clean(df,'0','Vehicle','Seller','Vehicle')

clean(df,'0','Body type','Doors','Doors')
clean(df,'0','Doors','Seats','Seats')

clean(df,'0','ext / int','Reg','Colour')
clean(df,'0','Kilometres','Colour','Kilometres')

clean(df,'0','Body type',',','Body')
clean(df,'0','Transmission','Engine','Transmission')

clean(df,'0','Drive type','Fuel type','Drive')
clean(df,'0','Fuel type','Fuel','Fuel_type')

clean(df,'0','Engine','Drive','Engine')
clean(df,'0','consumption','Kilometres','Fuel_consumption')

# %%
# We can see that our Price Column is not completely clean
df['Price']
# Out:
# 0                                                  $18,990
# 1                                                  $54,990
# 2                                                  $36,550
# 3                                                  $10,680
# 4        $27,990                      \n\n\nVehicle\n20...
#                                ...
# 22473    $43,000                      \n\n\nVehicle\n20...
# 22474    $63,190                      \n\n\nVehicle\n20...
# 22475    $39,000                      \n\n\nVehicle\n20...
# 22476    $45,000                      \n\n\nVehicle\n20...
# 22477    $84,100                      \n\n\nVehicle\n20...
# Name: Price, Length: 22478, dtype: object

# %%
# We need to split and strip again
df['Price'] = df['Price'].str.split('\n').str[0].str.strip()
df['Price']
# Out:
# 0        $18,990
# 1        $54,990
# 2        $36,550
# 3        $10,680
# 4        $27,990
#           ...
# 22473    $43,000
# 22474    $63,190
# 22475    $39,000
# 22476    $45,000
# 22477    $84,100
# Name: Price, Length: 22478, dtype: object

# %%
df['Body'] = df['Body'].str.split('\n').str[0].str.strip()

# %%
# We have some syntax issues in most columns that need to be replaced
df.head(2)
# Out:
#                                                    0    Price  \
# 0  \n\nPrice\n$18,990                        Calc...  $18,990
# 1  \n\nPrice\n$54,990                        Calc...  $54,990
#
#                                              Vehicle     Doors Seats  \
# 0                    2012 Ford Falcon XR6 FG Upgrade  Sedan, 4   , 5
# 1  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...    SUV, 4   , 7
#
#        Colour  Kilometres   Body Transmission Drive Fuel_type        Engine  \
# 0  Silver / -  134,301 km  Sedan    Automatic  Rear  Unleaded    6 cyl, 4 L
# 1    Grey / -   79,553 km    SUV    Automatic   4WD    Diesel  4 cyl, 2.8 L
#
#   Fuel_consumption
# 0   9.9 L / 100 km
# 1     8 L / 100 km

# %%
# Creating a function to replace any punctuation or syntax issues
def replacing(col,syntax,d=''):
    df[col] = df[col].str.replace(syntax,d)

# %%
# We want to drop the dollar sign and comma so we can change this data type into an integer
replacing('Price','$') 
replacing('Price',',')

# We want to drop the km and comma so we can change this data type into an integer
replacing('Kilometres','km')
replacing('Kilometres',',')

replacing('Seats',',')
replacing('Fuel_consumption','L / 100 km')

df = df.replace('-',np.nan)
# Out:
# /Users/garethbayvel/Desktop/Anaconda3/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# We can see that we have mostly cleaned up our columns but now we want to extract their numeric values only
df
# Out:
#                                                        0  Price  \
# 0      \n\nPrice\n$18,990                        Calc...  18990
# 1      \n\nPrice\n$54,990                        Calc...  54990
# 2      \n\nPrice\n$36,550                        Calc...  36550
# 3      \n\nPrice\n$10,680                        Calc...  10680
# 4      \n\nPrice\n$27,990                      \n\n\n...  27990
# ...                                                  ...    ...
# 22473  \n\nPrice\n$43,000                      \n\n\n...  43000
# 22474  \n\nPrice\n$63,190                      \n\n\n...  63190
# 22475  \n\nPrice\n$39,000                      \n\n\n...  39000
# 22476  \n\nPrice\n$45,000                      \n\n\n...  45000
# 22477  \n\nPrice\n$84,100                      \n\n\n...  84100
#
#                                                  Vehicle            Doors  \
# 0                        2012 Ford Falcon XR6 FG Upgrade         Sedan, 4
# 1      2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...           SUV, 4
# 2                  2016 Holden Colorado LS (4X4) RG MY16    Ute / Tray, 4
# 3                              2008 Honda Civic VTI MY07         Sedan, 4
# 4                       2020 Hyundai I30 Active PD2 MY20     Hatchback, 4
# ...                                                  ...              ...
# 22473        2021 Hyundai Tucson Elite (AWD) NX4.V1 MY22           SUV, 4
# 22474           2021 Ford Transit 410L (RWD) SRW VO MY21  People Mover, 3
# 22475        2021 Hyundai Tucson Elite (FWD) NX4.V1 MY22           SUV, 4
# 22476        2021 Hyundai Tucson Elite (AWD) NX4.V1 MY22           SUV, 4
# 22477    2021 Mercedes-Benz C200 Night Edition C205 MY21         Coupe, 2
#
#       Seats                                             Colour  \
# 0         5                                         Silver / -
# 1         7                                           Grey / -
# 2         5                                         Silver / -
# 3         5                                          Brown / -
# 4         5                   Polar White / Charcoal and Black
# ...     ...                                                ...
# 22473     5  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...
# 22474    12  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...
# 22475     5  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...
# 22476     5  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...
# 22477     4  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...
#
#                         Kilometres          Body Transmission  Drive  \
# 0                          134301          Sedan    Automatic   Rear
# 1                           79553            SUV    Automatic    4WD
# 2                           71293     Ute / Tray       Manual    4WD
# 3                           88621          Sedan    Automatic  Front
# 4      23580 \n\n\nCondition\nUsed     Hatchback    Automatic  Front
# ...                            ...           ...          ...    ...
# 22473                          NaN           SUV    Automatic    AWD
# 22474                          NaN  People Mover    Automatic   Rear
# 22475                          NaN           SUV    Automatic  Front
# 22476                          NaN           SUV    Automatic    AWD
# 22477                          NaN         Coupe    Automatic   Rear
#
#       Fuel_type        Engine  \
# 0      Unleaded    6 cyl, 4 L
# 1        Diesel  4 cyl, 2.8 L
# 2        Diesel  4 cyl, 2.8 L
# 3      Unleaded  4 cyl, 1.8 L
# 4      Unleaded    4 cyl, 2 L
# ...         ...           ...
# 22473  Unleaded         4 cyl
# 22474    Diesel    4 cyl, 2 L
# 22475  Unleaded         4 cyl
# 22476    Diesel         4 cyl
# 22477  Unleaded         4 cyl
#
#                                         Fuel_consumption
# 0                                                   9.9
# 1                                                     8
# 2                                                   7.9
# 3                                                   7.2
# 4                                                   7.4
# ...                                                  ...
# 22473  7.1 \n\n\nColour ext / int\n- / -\n\n\nWarrant...
# 22474  0 \n\n\nColour ext / int\n- / -\n\n\nWarranty\...
# 22475  8.1 \n\n\nColour ext / int\n- / -\n\n\nWarrant...
# 22476  6.3 \n\n\nColour ext / int\n- / -\n\n\nWarrant...
# 22477  7 \n\n\nColour ext / int\n- / -\n\n\nWarranty\...
#
# [22478 rows x 13 columns]

# %%
# This function allows us to extract the numeric values for each column using regular expression
def extracting_numbers(column_name):
    df[column_name] = df[column_name].str.extract('([\d]+)',expand=False).astype(int, errors = 'ignore')

# %%
extracting_numbers('Price') # Extracting only the price
extracting_numbers('Fuel_consumption') # Extracting only the fuel consumption integer
extracting_numbers('Doors') # Allows us to drop the Body type and be left with the number of doors only
extracting_numbers('Engine') # We only want the first number denoting cylinders
extracting_numbers('Seats') # Cleaning up any left over text
extracting_numbers('Kilometres') # Cleaning up any left over text

# %%
df.head(2)
# Out:
#                                                    0  Price  \
# 0  \n\nPrice\n$18,990                        Calc...  18990
# 1  \n\nPrice\n$54,990                        Calc...  54990
#
#                                              Vehicle Doors Seats      Colour  \
# 0                    2012 Ford Falcon XR6 FG Upgrade     4     5  Silver / -
# 1  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...     4     7    Grey / -
#
#   Kilometres   Body Transmission Drive Fuel_type Engine Fuel_consumption
# 0     134301  Sedan    Automatic  Rear  Unleaded      6                9
# 1      79553    SUV    Automatic   4WD    Diesel      4                8

# %%
# For our Anlysis we would expect year and price to be corellated so we need to create a year column
df['Year'] = df['Vehicle'].str.split(' ').str[0]

# Droping our 0 columns
df.drop(columns='0',inplace=True)

# %%
# Our data is looking failry clean at the moment but our Colour Column still contains syntax errors
df
# Out:
#        Price                                            Vehicle Doors Seats  \
# 0      18990                    2012 Ford Falcon XR6 FG Upgrade     4     5
# 1      54990  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...     4     7
# 2      36550              2016 Holden Colorado LS (4X4) RG MY16     4     5
# 3      10680                          2008 Honda Civic VTI MY07     4     5
# 4      27990                   2020 Hyundai I30 Active PD2 MY20     4     5
# ...      ...                                                ...   ...   ...
# 22473  43000        2021 Hyundai Tucson Elite (AWD) NX4.V1 MY22     4     5
# 22474  63190           2021 Ford Transit 410L (RWD) SRW VO MY21     3    12
# 22475  39000        2021 Hyundai Tucson Elite (FWD) NX4.V1 MY22     4     5
# 22476  45000        2021 Hyundai Tucson Elite (AWD) NX4.V1 MY22     4     5
# 22477  84100    2021 Mercedes-Benz C200 Night Edition C205 MY21     2     4
#
#                                                   Colour Kilometres  \
# 0                                             Silver / -     134301
# 1                                               Grey / -      79553
# 2                                             Silver / -      71293
# 3                                              Brown / -      88621
# 4                       Polar White / Charcoal and Black      23580
# ...                                                  ...        ...
# 22473  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...        NaN
# 22474  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...        NaN
# 22475  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...        NaN
# 22476  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...        NaN
# 22477  - / -\n\n\nWarranty\n5 years / Unlimited km\n\...        NaN
#
#                Body Transmission  Drive Fuel_type Engine Fuel_consumption  \
# 0             Sedan    Automatic   Rear  Unleaded      6                9
# 1               SUV    Automatic    4WD    Diesel      4                8
# 2        Ute / Tray       Manual    4WD    Diesel      4                7
# 3             Sedan    Automatic  Front  Unleaded      4                7
# 4         Hatchback    Automatic  Front  Unleaded      4                7
# ...             ...          ...    ...       ...    ...              ...
# 22473           SUV    Automatic    AWD  Unleaded      4                7
# 22474  People Mover    Automatic   Rear    Diesel      4                0
# 22475           SUV    Automatic  Front  Unleaded      4                8
# 22476           SUV    Automatic    AWD    Diesel      4                6
# 22477         Coupe    Automatic   Rear  Unleaded      4                7
#
#        Year
# 0      2012
# 1      2015
# 2      2016
# 3      2008
# 4      2020
# ...     ...
# 22473  2021
# 22474  2021
# 22475  2021
# 22476  2021
# 22477  2021
#
# [22478 rows x 13 columns]

# %%
df['Colour'].value_counts().head(30)
# Out:
# White / -                                                                3420
# - / -\n\n\nWarranty\n5 years / Unlimited km\n\n\nCountry of origin\n-    3030
# Silver / -                                                               1410
# Grey / -                                                                 1155
# - / -\n\n\nWarranty\n3 years / Unlimited km\n\n\nCountry of origin\n-    1012
# Blue / -                                                                  953
# - / -\n\n\nWarranty\n3 years / 200,000 km\n\n\nCountry of origin\n-       894
# Black / -                                                                 871
# - / -\n\n\nWarranty\n3 years / 100,000 km\n\n\nCountry of origin\n-       842
# Red / -                                                                   769
# - / -\n\n\nWarranty\n3 years / 150,000 km\n\n\nCountry of origin\n-       622
# White / Black                                                             490
# - / -                                                                     479
# - / -\n\n\nWarranty\n4 years / 100,000 km\n\n\nCountry of origin\n-       344
# White / Grey                                                              299
# - / -\n\n\nWarranty\n2 years / 500,000 km\n\n\nCountry of origin\n-       296
# - / -\n\n\nWarranty\n3 years / 250,000 km\n\n\nCountry of origin\n-       280
# - / -\n\n\nWarranty\n5 years / 250,000 km\n\n\nCountry of origin\n-       278
# Silver / Black                                                            270
# - / -\n\n\nWarranty\n7 years / Unlimited km\n\n\nCountry of origin\n-     232
# Grey / Black                                                              221
# - / -\n\n\nWarranty\n5 years / 100,000 km\n\n\nCountry of origin\n-       200
# Black / Black                                                             186
# Blue / Black                                                              167
# Silver / Grey                                                             140
# Red / Black                                                               117
# - / -\n\n\nWarranty\n3 years / 500,000 km\n\n\nCountry of origin\n-       116
# - / -\n\n\nWarranty\n3 years / 160,000 km\n\n\nCountry of origin\n-       114
# Yellow / -                                                                111
# Green / -                                                                 104
# Name: Colour, dtype: int64

# %%
df['Colour'] = df['Colour'].str.replace('/ -','').str.strip()#Most of our colours have / - almost as a suffix we need this removed
df['Colour'] = df['Colour'].str.replace('-', 'Unknown')

# Since most of our rows have wording containg specific identifiers we can use these to replace then with Unkowns
df['Colour'] = np.where(df['Colour'].str.contains('\n\n'),'Unknown',df['Colour']) 
df['Colour'] = df['Colour'].str.split('/').str[0].str.strip()

df['Colour'] = df['Colour'].str.lower()# Fix upper or lower case entries

df['Colour'].value_counts()
# Out:
# unknown                                                 9096
# white                                                   4790
# silver                                                  2074
# grey                                                    1721
# blue                                                    1419
# black                                                   1326
# red                                                     1110
# green                                                    152
# yellow                                                   151
# gold                                                     143
# orange                                                   126
# brown                                                     86
# pearl white                                               13
# purple                                                    10
# beige                                                      9
# metallic blue                                              8
# champagne                                                  5
# metallic silver                                            5
# gray                                                       5
# splash white                                               4
# rosegold                                                   4
# charcoal                                                   3
# titanium                                                   3
# polar white                                                3
# metalic blue                                               3
# bronze                                                     3
# metallic grey                                              3
# gun metal grey                                             3
# metallic black                                             3
# midnight blue                                              3
# graphite                                                   2
# steel silver                                               2
# atomic orange                                              2
# denim                                                      2
# kinetic blue                                               2
# silver pearl                                               2
# snowflake white                                            2
# miami blue                                                 2
# soul red                                                   2
# metallic pearl white                                       2
# indium grey                                                2
# burgundy                                                   2
# nitrate                                                    2
# orange rock                                                2
# blaze orange                                               2
# silver sky                                                 2
# matt grey                                                  2
# wr mica blue with white stripes                            2
# snow white pearl                                           2
# bright silver                                              2
# fuji white                                                 2
# persian grey                                               2
# blizzard                                                   2
# bright white                                               2
# quartz grey                                                2
# bronze copper unique accents over subaru white pearl       2
# stromboli grey                                             2
# pyrite brown                                               2
# voodoo blue                                                2
# diablo red                                                 2
# colour                                                     2
# heritage green                                             2
# peacock black                                              2
# liquid beige                                               2
# cashmere white matte                                       2
# hot house green                                            2
# graphite grey                                              2
# gunmetal grey                                              2
# arctic white                                               2
# midnight                                                   2
# emperor                                                    2
# some like it hot                                           2
# charcoal grey                                              2
# charchol                                                   2
# dark green                                                 2
# metalic silver grey                                        2
# modern steel                                               2
# crystal pearl                                              2
# pink                                                       2
# chicane yellow                                             2
# soul red metallic                                          2
# indus silver                                               2
# mineral white                                              2
# phantom black                                              2
# navarra blue                                               2
# bathurst black                                             2
# metalic green                                              2
# snowflake pearl white                                      1
# light blue                                                 1
# corris grey                                                1
# clear white                                                1
# metallic white                                             1
# abalone white                                              1
# lt blue mica metallic                                      1
# sliver                                                     1
# shadow black                                               1
# tumeric                                                    1
# metal steel                                                1
# pure silver                                                1
# sandy taupe                                                1
# hyper blue                                                 1
# glacier white                                              1
# blue onyx                                                  1
# silver aluminium                                           1
# mars rock                                                  1
# gold and black                                             1
# aa yellow                                                  1
# mineral black                                              1
# stornoway grey                                             1
# grey metallic                                              1
# ehite                                                      1
# silky pearl white                                          1
# glacier whote                                              1
# silver nitrate                                             1
# calcite white                                              1
# odyssey blue                                               1
# coris grey                                                 1
# black pearl metallic                                       1
# velocity orange                                            1
# off white                                                  1
# cosmos black                                               1
# fd trim                                                    1
# camellia red                                               1
# sand beige                                                 1
# graphite grey metallic                                     1
# sole red                                                   1
# siver                                                      1
# ivory pearl                                                1
# cosmo blue                                                 1
# champagne lime                                             1
# diamond black                                              1
# sable brown                                                1
# summit white                                               1
# black sapphire                                             1
# perfect blue                                               1
# midnight black                                             1
# navy blue                                                  1
# british racing green                                       1
# barrents blue                                              1
# burgandy                                                   1
# firey red                                                  1
# black silhouette                                           1
# galaxy blue silica                                         1
# dark grey metalic                                          1
# black roof red body                                        1
# storm grey metallic                                        1
# sunshine yellow                                            1
# sea blue                                                   1
# glacier                                                    1
# mecure grey                                                1
# two tone white with grey trim                              1
# silvery blue                                               1
# burnt orange                                               1
# artic white                                                1
# chili red                                                  1
# opal beige metallic                                        1
# pearl white metallic duco                                  1
# pearl blue                                                 1
# marmalade                                                  1
# machine grey                                               1
# orange fury                                                1
# cosmic black                                               1
# predawn grey                                               1
# fiery red                                                  1
# met grey                                                   1
# electric silver                                            1
# smokey blue                                                1
# Name: Colour, dtype: int64

# %%
# We have multicoloured cars for example metalic white which we wont to be unicolour
colour_dict = dict(df['Colour'].value_counts()) 
colour_list = list(colour_dict.keys())[:12]# creating a list of the 12 most popular colours
colour_list
# Out:
# ['unknown',
#  'white',
#  'silver',
#  'grey',
#  'blue',
#  'black',
#  'red',
#  'green',
#  'yellow',
#  'gold',
#  'orange',
#  'brown']

# %%
# This function searches for multicoloured cars containing a colour element from our above list and converts it
def color_change(color,column):
    df[column] = np.where(df[column].str.contains(color),color,df[column])

# %%
# Running a for loop so we do not have to do use our function 12 seperate times
for x in colour_list:
    color_change(x,'Colour')

# %%
# We have significanlty reduced our colours into something more manageable
df['Colour'].value_counts()
# Out:
# unknown                9096
# white                  4842
# silver                 2096
# grey                   1754
# blue                   1454
# black                  1346
# red                    1121
# green                   161
# yellow                  155
# gold                    147
# orange                  135
# brown                    89
# purple                   10
# beige                     9
# gray                      5
# champagne                 5
# charcoal                  3
# titanium                  3
# bronze                    3
# liquid beige              2
# colour                    2
# burgundy                  2
# nitrate                   2
# blizzard                  2
# midnight                  2
# denim                     2
# emperor                   2
# some like it hot          2
# charchol                  2
# pink                      2
# crystal pearl             2
# graphite                  2
# modern steel              2
# sandy taupe               1
# sliver                    1
# ehite                     1
# glacier whote             1
# sand beige                1
# fd trim                   1
# metal steel               1
# siver                     1
# tumeric                   1
# mars rock                 1
# marmalade                 1
# glacier                   1
# burgandy                  1
# champagne lime            1
# opal beige metallic       1
# ivory pearl               1
# Name: Colour, dtype: int64

# %% [markdown]
# ## Data Cleaning and Wrangling

# %%
# Always look for duplicated data points especially when webscraping data
df[df['Vehicle'] == '2021 Ford Transit 410L (RWD) SRW VO MY21'] # We have clearly duplicated data from our webscraping
# Out:
#        Price                                   Vehicle Doors Seats   Colour  \
# 10546  63190  2021 Ford Transit 410L (RWD) SRW VO MY21     3    12  unknown
# 22474  63190  2021 Ford Transit 410L (RWD) SRW VO MY21     3    12  unknown
#
#       Kilometres          Body Transmission Drive Fuel_type Engine  \
# 10546        NaN  People Mover    Automatic  Rear    Diesel      4
# 22474        NaN  People Mover    Automatic  Rear    Diesel      4
#
#       Fuel_consumption  Year
# 10546                0  2021
# 22474                0  2021

# %%
# By default drop_duplicates uses all columns we is exactly what we want in this instance
df = df.drop_duplicates()

# %%
# We can see that almost half of our data was duplicated and this would have impacted our statistical analysis
# We also need to reset our index as we have 13468 but our index goes up to 18004. We will do this after droping
df
# Out:
#        Price                                            Vehicle Doors Seats  \
# 0      18990                    2012 Ford Falcon XR6 FG Upgrade     4     5
# 1      54990  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...     4     7
# 2      36550              2016 Holden Colorado LS (4X4) RG MY16     4     5
# 3      10680                          2008 Honda Civic VTI MY07     4     5
# 4      27990                   2020 Hyundai I30 Active PD2 MY20     4     5
# ...      ...                                                ...   ...   ...
# 17572    NaN                   2005 Mazda Tribute Limited Sport     4     5
# 17697    NaN          2018 Toyota Fortuner Crusade GUN156R MY19     4     7
# 17883    NaN              2018 Toyota Yaris Ascent NCP130R MY17     5     5
# 17972    NaN             2013 Hyundai Veloster SR Turbo FS MY13     3     4
# 18004    NaN                 2015 Toyota Tarago GLI ACR50R MY13     4     8
#
#        Colour Kilometres        Body Transmission  Drive Fuel_type Engine  \
# 0      silver     134301       Sedan    Automatic   Rear  Unleaded      6
# 1        grey      79553         SUV    Automatic    4WD    Diesel      4
# 2      silver      71293  Ute / Tray       Manual    4WD    Diesel      4
# 3       brown      88621       Sedan    Automatic  Front  Unleaded      4
# 4       white      23580   Hatchback    Automatic  Front  Unleaded      4
# ...       ...        ...         ...          ...    ...       ...    ...
# 17572  silver     197038         SUV    Automatic    4WD  Unleaded      6
# 17697    grey      52704         SUV    Automatic    AWD    Diesel      4
# 17883  orange      14117   Hatchback    Automatic  Front  Unleaded      4
# 17972     red      69294   Hatchback    Automatic  Front  Unleaded      4
# 18004  silver      77021       Wagon    Automatic  Front  Unleaded      4
#
#       Fuel_consumption  Year
# 0                    9  2012
# 1                    8  2015
# 2                    7  2016
# 3                    7  2008
# 4                    7  2020
# ...                ...   ...
# 17572               12  2005
# 17697                8  2018
# 17883                6  2018
# 17972                6  2013
# 18004                8  2015
#
# [13467 rows x 13 columns]

# %%
# Looking at the missing values contained in our dataframe
klib.missingval_plot(df)
print(df.isnull().sum()/df.shape[0])
# Out:
# Price               0.014480
# Vehicle             0.000074
# Doors               0.000074
# Seats               0.024876
# Colour              0.000000
# Kilometres          0.260266
# Body                0.000074
# Transmission        0.074181
# Drive               0.000074
# Fuel_type           0.017821
# Engine              0.019603
# Fuel_consumption    0.070543
# Year                0.000074
# dtype: float64

# %% [markdown]
# ## Rule of Thumb
#
# I normally drop rows that have 1% or 2% missing values in a dataset this size. Notably, we are dropping missing price as it is our dependent variable. We can see that vehicles, doors, colour, body, transmission, drive, fuel_type and year are all missing less than 0.001% of data points. Additionaly, we see corellations between missing values between most columns and as a result we want to drop rows according to a certain threshold of missing values
#
# * We will leave missing KM values as a car with no KM recorded may have a correlation with car price

# %%
df[df['Seats'].isnull()].tail()
# Out:
#         Price                            Vehicle Doors Seats Colour  \
# 16031     NaN         2020 Mercedes-Benz A-CLASS    20   NaN   blue
# 16041     NaN        2018 Mercedes-Benz Sprinter    18   NaN  white
# 16445  149711  2019 Ram 1500 Laramie (No Series)     5   NaN  white
# 16525   19711             2012 Ford Ranger XL PX     5   NaN  white
# 16705     NaN          2000 Land Rover Discovery   386   NaN    red
#
#       Kilometres          Body Transmission  Drive Fuel_type Engine  \
# 16031         20     Hatchback          NaN  Other       NaN    NaN
# 16041      18966  People Mover          NaN  Other       NaN    NaN
# 16445       9880    Ute / Tray          NaN  Other    Diesel      3
# 16525     226091    Ute / Tray          NaN  Other    Diesel      2
# 16705     386243         Wagon          NaN  Other       NaN    NaN
#
#       Fuel_consumption  Year
# 16031              NaN  2020
# 16041              NaN  2018
# 16445              NaN  2019
# 16525              NaN  2012
# 16705              NaN  2000

# %%
df = df.dropna(thresh = 6)

# %%
df = df.dropna(subset=['Price','Vehicle','Doors','Colour','Body','Drive','Fuel_type'])
df.reset_index(inplace = True, drop = True) # Resetting our Index
df
# Out:
#        Price                                            Vehicle Doors Seats  \
# 0      18990                    2012 Ford Falcon XR6 FG Upgrade     4     5
# 1      54990  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...     4     7
# 2      36550              2016 Holden Colorado LS (4X4) RG MY16     4     5
# 3      10680                          2008 Honda Civic VTI MY07     4     5
# 4      27990                   2020 Hyundai I30 Active PD2 MY20     4     5
# ...      ...                                                ...   ...   ...
# 13044  40000                   2016 Mazda CX-9 Azami (awd) MY16     4     7
# 13045  30995                         2019 Mazda 3 G20 Evolve BP     5     5
# 13046  16995                                2014 Mazda 3 NEO BM     5     5
# 13047  13995               2014 Ford Focus Trend LW MK2 Upgrade     5     5
# 13048  10990                     2012 Mazda 3 NEO BL 11 Upgrade     4     5
#
#        Colour Kilometres        Body Transmission  Drive Fuel_type Engine  \
# 0      silver     134301       Sedan    Automatic   Rear  Unleaded      6
# 1        grey      79553         SUV    Automatic    4WD    Diesel      4
# 2      silver      71293  Ute / Tray       Manual    4WD    Diesel      4
# 3       brown      88621       Sedan    Automatic  Front  Unleaded      4
# 4       white      23580   Hatchback    Automatic  Front  Unleaded      4
# ...       ...        ...         ...          ...    ...       ...    ...
# 13044    grey     142433         SUV    Automatic    AWD  Unleaded      4
# 13045     red       8623   Hatchback    Automatic  Front  Unleaded      4
# 13046     red      38381   Hatchback    Automatic  Front  Unleaded      4
# 13047   black      55050   Hatchback    Automatic  Front  Unleaded      4
# 13048   white     126328       Sedan       Manual  Front  Unleaded      4
#
#       Fuel_consumption  Year
# 0                    9  2012
# 1                    8  2015
# 2                    7  2016
# 3                    7  2008
# 4                    7  2020
# ...                ...   ...
# 13044                8  2016
# 13045                6  2019
# 13046                5  2014
# 13047                6  2014
# 13048                7  2012
#
# [13049 rows x 13 columns]

# %%
# Looking at the missing values contained in our dataframe
klib.missingval_plot(df)
print(df.isnull().sum()/df.shape[0])
# Out:
# Price               0.000000
# Vehicle             0.000000
# Doors               0.000000
# Seats               0.010882
# Colour              0.000000
# Kilometres          0.265538
# Body                0.000000
# Transmission        0.057782
# Drive               0.000000
# Fuel_type           0.000000
# Engine              0.006514
# Fuel_consumption    0.052341
# Year                0.000000
# dtype: float64

# %%
# Seats and Engine now only have below 0.01% missing values
df = df.dropna(subset=['Seats','Engine'])
df.reset_index(inplace = True, drop = True) # Resetting our Index
df
# Out:
#        Price                                            Vehicle Doors Seats  \
# 0      18990                    2012 Ford Falcon XR6 FG Upgrade     4     5
# 1      54990  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...     4     7
# 2      36550              2016 Holden Colorado LS (4X4) RG MY16     4     5
# 3      10680                          2008 Honda Civic VTI MY07     4     5
# 4      27990                   2020 Hyundai I30 Active PD2 MY20     4     5
# ...      ...                                                ...   ...   ...
# 12856  40000                   2016 Mazda CX-9 Azami (awd) MY16     4     7
# 12857  30995                         2019 Mazda 3 G20 Evolve BP     5     5
# 12858  16995                                2014 Mazda 3 NEO BM     5     5
# 12859  13995               2014 Ford Focus Trend LW MK2 Upgrade     5     5
# 12860  10990                     2012 Mazda 3 NEO BL 11 Upgrade     4     5
#
#        Colour Kilometres        Body Transmission  Drive Fuel_type Engine  \
# 0      silver     134301       Sedan    Automatic   Rear  Unleaded      6
# 1        grey      79553         SUV    Automatic    4WD    Diesel      4
# 2      silver      71293  Ute / Tray       Manual    4WD    Diesel      4
# 3       brown      88621       Sedan    Automatic  Front  Unleaded      4
# 4       white      23580   Hatchback    Automatic  Front  Unleaded      4
# ...       ...        ...         ...          ...    ...       ...    ...
# 12856    grey     142433         SUV    Automatic    AWD  Unleaded      4
# 12857     red       8623   Hatchback    Automatic  Front  Unleaded      4
# 12858     red      38381   Hatchback    Automatic  Front  Unleaded      4
# 12859   black      55050   Hatchback    Automatic  Front  Unleaded      4
# 12860   white     126328       Sedan       Manual  Front  Unleaded      4
#
#       Fuel_consumption  Year
# 0                    9  2012
# 1                    8  2015
# 2                    7  2016
# 3                    7  2008
# 4                    7  2020
# ...                ...   ...
# 12856                8  2016
# 12857                6  2019
# 12858                5  2014
# 12859                6  2014
# 12860                7  2012
#
# [12861 rows x 13 columns]

# %%
print(df.isnull().sum()/df.shape[0])
# Out:
# Price               0.000000
# Vehicle             0.000000
# Doors               0.000000
# Seats               0.000000
# Colour              0.000000
# Kilometres          0.266076
# Body                0.000000
# Transmission        0.046886
# Drive               0.000000
# Fuel_type           0.000000
# Engine              0.000000
# Fuel_consumption    0.041521
# Year                0.000000
# dtype: float64

# %% [markdown]
# ## Correcting Our Data Types
#
# Through this process we will unvail any discrepancies within rows, for example letters in price or seat numbers etc

# %%
# Checking our data types
# Price, Doors, Seats, Kilometres, Engine and Fuel_consumption can be turned into integers
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12861 entries, 0 to 12860
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             12861 non-null  object
#  1   Vehicle           12861 non-null  object
#  2   Doors             12861 non-null  object
#  3   Seats             12861 non-null  object
#  4   Colour            12861 non-null  object
#  5   Kilometres        9439 non-null   object
#  6   Body              12861 non-null  object
#  7   Transmission      12258 non-null  object
#  8   Drive             12861 non-null  object
#  9   Fuel_type         12861 non-null  object
#  10  Engine            12861 non-null  object
#  11  Fuel_consumption  12327 non-null  object
#  12  Year              12861 non-null  object
# dtypes: object(13)
# memory usage: 1.3+ MB

# %%
df1 = df.copy()

# %%
df1['Price'] = pd.to_numeric(df1['Price'])
df1['Doors'] = pd.to_numeric(df1['Doors'])
df1['Seats'] = pd.to_numeric(df1['Seats'])
df1['Kilometres'] = pd.to_numeric(df1['Kilometres'])
df1['Engine'] = pd.to_numeric(df1['Engine'])
df1['Fuel_consumption'] = pd.to_numeric(df1['Fuel_consumption'])
df1['Year'] = pd.to_numeric(df1['Year'])

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12861 entries, 0 to 12860
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             12861 non-null  int64
#  1   Vehicle           12861 non-null  object
#  2   Doors             12861 non-null  int64
#  3   Seats             12861 non-null  int64
#  4   Colour            12861 non-null  object
#  5   Kilometres        9439 non-null   float64
#  6   Body              12861 non-null  object
#  7   Transmission      12258 non-null  object
#  8   Drive             12861 non-null  object
#  9   Fuel_type         12861 non-null  object
#  10  Engine            12861 non-null  int64
#  11  Fuel_consumption  12327 non-null  float64
#  12  Year              12861 non-null  int64
# dtypes: float64(2), int64(5), object(6)
# memory usage: 1.3+ MB

# %% [markdown]
# ## Exploratory Data Analysis
#
# We will start with our quantitative independent variables:
# - **Univariate Analysis** (Shape, Distribution, skewness, Transformation)
# - **Bivaraite Analysis** (Correlation with Price)

# %% [markdown]
# ### Price Statistical Plots
#
# We expect this to be very right skewed as luxury cars are contained within this dataset and are in excess of $200,000

# %%
sns.displot(df1['Price'],kde = True)

# %%
klib.dist_plot(df1['Price'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ##### Our plots and Skewness statistic over 1 indicates it is heavilty right skewed. We may have to transform price to make it more normally distributed

# %%
sns.displot(np.log(df1['Price']),kde = True)

# %%
klib.dist_plot(np.log(df1['Price']))
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# ##### Log transforming Price has created a more Normally Distributed distribution (failry symmetric) evidenced by a skewness <1

# %% [markdown]
# ### Kilometers Statistical Plots
#
# We expect this to be very right skewed as cars within our dataset date back all the way to 1960 so we are expecting some very high numbers

# %%
sns.displot(df1['Kilometres'],kde = True)

# %%
klib.dist_plot(df1['Kilometres'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Kilometres', ylabel='Density'>

# %% [markdown]
# ##### Our plots and Skewness statistic over 1 indicates it is heavilty right skewed. We may have to transform price to make it more normally distributed

# %%
klib.dist_plot(np.sqrt(df1['Kilometres']))
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Kilometres', ylabel='Density'>

# %% [markdown]
# ##### Log transforming Price has created a more Normally Distributed distribution (failry symmetric) evidenced by a skewness <1

# %% [markdown]
# ### Year Statistical Plots
#
# It makes more sense to convert this into how old the car is (AGE)

# %%
# This is clearly left skewed
sns.displot(df1['Year'])

# %%
# Our skewness statistic confirms our left skew
# A Kurtosis greater than 3 indicates our data is heavily left tailed
klib.dist_plot(df1['Year'])
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
# Creating an Age column and shifting our data to be able to perform transformations and you cannot log/sqrt a negative
df1['age'] = 2021 - df1['Year'] +1

# %%
klib.dist_plot(np.sqrt(df1['age']))
# Out:
# Large dataset detected, using 10000 random samples for the plots. Summary statistics are still based on the entire dataset.
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# ##### Log transforming Age has created a more Normally Distributed distribution (failry symmetric) evidenced by a skewness <1

# %% [markdown]
# ### Considering a Box Cox Transformation for these columns

# %%
box_cox_data = df1[['Price','Kilometres','Year']]

for x in box_cox_data.columns:
    # generate non-normal data (exponential)
    original_data = df1[x].values
  
    # transform training data & save lambda value
    fitted_data, fitted_lambda = stats.boxcox(original_data)
  
    # creating axes to draw plots
    fig, ax = plt.subplots(1, 2)
  
    # plotting the original data(non-normal) and 
    # fitted data (normal)
    sns.kdeplot(original_data, label = "Non-Normal", color ="green", ax = ax[0], fill = True)
    
    sns.kdeplot(fitted_data, label = "Box Cox Transformation", color ="blue", ax = ax[1],fill = True)
  
    # adding legends to the subplots
    plt.legend()
    plt.title(x)
  
    # rescaling the subplots
    fig.set_figheight(5)
    fig.set_figwidth(10)
  
    print(f"Lambda value used for Transformation: {fitted_lambda}")
# Out:
# Lambda value used for Transformation: -0.06117475197288092
# Lambda value used for Transformation: 8.472135811722177
# /Users/garethbayvel/Desktop/Anaconda3/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /Users/garethbayvel/Desktop/Anaconda3/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:216: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(x, axis, dtype, out, keepdims)
# Lambda value used for Transformation: 46.81163473446615

# %% [markdown]
# ##### I think our transformations have achieved a failry symmetrical distribution and a Box Cox does not seem to achive this

# %%
# Creating our normally distributed Price, Kilometers and Age
df1['Log_price'] = np.log(df1['Price'])
df1['Sqrt_km'] = np.sqrt(df1['Kilometres'])
df1['Sqrt_age'] = np.sqrt(df1['age'])

# %%
df_transformed = df1.drop(['Price','Kilometres','age','Year'],axis=1)
df_transformed.head()
# Out:
#                                              Vehicle  Doors  Seats  Colour  \
# 0                    2012 Ford Falcon XR6 FG Upgrade      4      5  silver
# 1  2015 Toyota Landcruiser Prado GXL (4X4) GDJ150...      4      7    grey
# 2              2016 Holden Colorado LS (4X4) RG MY16      4      5  silver
# 3                          2008 Honda Civic VTI MY07      4      5   brown
# 4                   2020 Hyundai I30 Active PD2 MY20      4      5   white
#
#          Body Transmission  Drive Fuel_type  Engine  Fuel_consumption  \
# 0       Sedan    Automatic   Rear  Unleaded       6               9.0
# 1         SUV    Automatic    4WD    Diesel       4               8.0
# 2  Ute / Tray       Manual    4WD    Diesel       4               7.0
# 3       Sedan    Automatic  Front  Unleaded       4               7.0
# 4   Hatchback    Automatic  Front  Unleaded       4               7.0
#
#    Log_price     Sqrt_km  Sqrt_age
# 0   9.851668  366.471008  3.162278
# 1  10.914907  282.051414  2.645751
# 2  10.506436  267.007491  2.449490
# 3   9.276128  297.692795  3.741657
# 4  10.239603  153.557807  1.414214

# %%
klib.corr_mat(df_transformed)
# Out:
# <style  type="text/css" >
# #T_2f09d_row0_col0,#T_2f09d_row0_col1,#T_2f09d_row0_col3,#T_2f09d_row0_col6,#T_2f09d_row1_col0,#T_2f09d_row1_col1,#T_2f09d_row1_col3,#T_2f09d_row1_col5,#T_2f09d_row1_col6,#T_2f09d_row2_col2,#T_2f09d_row2_col3,#T_2f09d_row2_col4,#T_2f09d_row2_col5,#T_2f09d_row2_col6,#T_2f09d_row3_col0,#T_2f09d_row3_col1,#T_2f09d_row3_col2,#T_2f09d_row3_col3,#T_2f09d_row3_col5,#T_2f09d_row3_col6,#T_2f09d_row4_col2,#T_2f09d_row4_col4,#T_2f09d_row5_col1,#T_2f09d_row5_col2,#T_2f09d_row5_col3,#T_2f09d_row5_col5,#T_2f09d_row5_col6,#T_2f09d_row6_col0,#T_2f09d_row6_col1,#T_2f09d_row6_col2,#T_2f09d_row6_col3,#T_2f09d_row6_col5,#T_2f09d_row6_col6{
#             color:  None;
#         }#T_2f09d_row0_col2,#T_2f09d_row0_col4,#T_2f09d_row0_col5,#T_2f09d_row1_col2,#T_2f09d_row1_col4,#T_2f09d_row2_col0,#T_2f09d_row2_col1,#T_2f09d_row3_col4,#T_2f09d_row4_col0,#T_2f09d_row4_col1,#T_2f09d_row4_col3,#T_2f09d_row4_col5,#T_2f09d_row4_col6,#T_2f09d_row5_col0,#T_2f09d_row5_col4,#T_2f09d_row6_col4{
#             color:  #FF3344;
#         }</style><table id="T_2f09d_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Doors</th>        <th class="col_heading level0 col1" >Seats</th>        <th class="col_heading level0 col2" >Engine</th>        <th class="col_heading level0 col3" >Fuel_consumption</th>        <th class="col_heading level0 col4" >Log_price</th>        <th class="col_heading level0 col5" >Sqrt_km</th>        <th class="col_heading level0 col6" >Sqrt_age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2f09d_level0_row0" class="row_heading level0 row0" >Doors</th>
#                         <td id="T_2f09d_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_2f09d_row0_col1" class="data row0 col1" >0.45</td>
#                         <td id="T_2f09d_row0_col2" class="data row0 col2" >-0.17</td>
#                         <td id="T_2f09d_row0_col3" class="data row0 col3" >0.27</td>
#                         <td id="T_2f09d_row0_col4" class="data row0 col4" >-0.39</td>
#                         <td id="T_2f09d_row0_col5" class="data row0 col5" >-0.15</td>
#                         <td id="T_2f09d_row0_col6" class="data row0 col6" >0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row1" class="row_heading level0 row1" >Seats</th>
#                         <td id="T_2f09d_row1_col0" class="data row1 col0" >0.45</td>
#                         <td id="T_2f09d_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_2f09d_row1_col2" class="data row1 col2" >-0.02</td>
#                         <td id="T_2f09d_row1_col3" class="data row1 col3" >0.21</td>
#                         <td id="T_2f09d_row1_col4" class="data row1 col4" >-0.13</td>
#                         <td id="T_2f09d_row1_col5" class="data row1 col5" >0.01</td>
#                         <td id="T_2f09d_row1_col6" class="data row1 col6" >0.13</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row2" class="row_heading level0 row2" >Engine</th>
#                         <td id="T_2f09d_row2_col0" class="data row2 col0" >-0.17</td>
#                         <td id="T_2f09d_row2_col1" class="data row2 col1" >-0.02</td>
#                         <td id="T_2f09d_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_2f09d_row2_col3" class="data row2 col3" >0.28</td>
#                         <td id="T_2f09d_row2_col4" class="data row2 col4" >0.16</td>
#                         <td id="T_2f09d_row2_col5" class="data row2 col5" >0.10</td>
#                         <td id="T_2f09d_row2_col6" class="data row2 col6" >0.09</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row3" class="row_heading level0 row3" >Fuel_consumption</th>
#                         <td id="T_2f09d_row3_col0" class="data row3 col0" >0.27</td>
#                         <td id="T_2f09d_row3_col1" class="data row3 col1" >0.21</td>
#                         <td id="T_2f09d_row3_col2" class="data row3 col2" >0.28</td>
#                         <td id="T_2f09d_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_2f09d_row3_col4" class="data row3 col4" >-0.29</td>
#                         <td id="T_2f09d_row3_col5" class="data row3 col5" >0.18</td>
#                         <td id="T_2f09d_row3_col6" class="data row3 col6" >0.34</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row4" class="row_heading level0 row4" >Log_price</th>
#                         <td id="T_2f09d_row4_col0" class="data row4 col0" >-0.39</td>
#                         <td id="T_2f09d_row4_col1" class="data row4 col1" >-0.13</td>
#                         <td id="T_2f09d_row4_col2" class="data row4 col2" >0.16</td>
#                         <td id="T_2f09d_row4_col3" class="data row4 col3" >-0.29</td>
#                         <td id="T_2f09d_row4_col4" class="data row4 col4" >1.00</td>
#                         <td id="T_2f09d_row4_col5" class="data row4 col5" >-0.55</td>
#                         <td id="T_2f09d_row4_col6" class="data row4 col6" >-0.68</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row5" class="row_heading level0 row5" >Sqrt_km</th>
#                         <td id="T_2f09d_row5_col0" class="data row5 col0" >-0.15</td>
#                         <td id="T_2f09d_row5_col1" class="data row5 col1" >0.01</td>
#                         <td id="T_2f09d_row5_col2" class="data row5 col2" >0.10</td>
#                         <td id="T_2f09d_row5_col3" class="data row5 col3" >0.18</td>
#                         <td id="T_2f09d_row5_col4" class="data row5 col4" >-0.55</td>
#                         <td id="T_2f09d_row5_col5" class="data row5 col5" >1.00</td>
#                         <td id="T_2f09d_row5_col6" class="data row5 col6" >0.79</td>
#             </tr>
#             <tr>
#                         <th id="T_2f09d_level0_row6" class="row_heading level0 row6" >Sqrt_age</th>
#                         <td id="T_2f09d_row6_col0" class="data row6 col0" >0.14</td>
#                         <td id="T_2f09d_row6_col1" class="data row6 col1" >0.13</td>
#                         <td id="T_2f09d_row6_col2" class="data row6 col2" >0.09</td>
#                         <td id="T_2f09d_row6_col3" class="data row6 col3" >0.34</td>
#                         <td id="T_2f09d_row6_col4" class="data row6 col4" >-0.68</td>
#                         <td id="T_2f09d_row6_col5" class="data row6 col5" >0.79</td>
#                         <td id="T_2f09d_row6_col6" class="data row6 col6" >1.00</td>
#             </tr>
#     </tbody></table>

# %%
sns.heatmap(df_transformed.corr(),annot = True)
# Out:
# <AxesSubplot:>
